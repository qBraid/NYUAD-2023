# %%
# !qbraid jobs enable qiskit
# Out:
# You have already enabled qBraid Quantum Jobs in the qiskit environment.

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_provider import IBMProvider
service = QiskitRuntimeService(channel="ibm_quantum")
backend = service.get_backend("ibmq_jakarta")

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.extensions import UnitaryGate
import numpy as np

# %%
from qiskit import QuantumCircuit, transpile
from qiskit.circuit.gate import Gate
from qiskit.circuit.library.standard_gates import HGate, CZGate, RYGate, XGate

# %%
qubit = QuantumRegister(2)
circ = QuantumCircuit (qubit)
param = 1

# %%
    # Apply hadamard on both qubits
circ.append(HGate(), [qubit[0]])
circ.append(HGate(), [qubit[1]])
# Apply a two qubit CZ gate
circ.append(CZGate(), [qubit[0], qubit[1]])
# Apply RY of pi.2 on both qubits
circ.append(RYGate(param), [qubit[0]])
circ.append(RYGate(-param), [qubit[1]])
        # Apply a two qubit CZ gate
circ.append(CZGate(), [qubit[0], qubit[1]])
        # Apply Hadamard on both qubits
circ.append(HGate(), [qubit[0]])
circ.append(HGate(), [qubit[1]])

# %%
circ.draw(output='mpl')
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 circ.draw(output='mpl')
#
# File ~/.qbraid/environments/qiskit_9y9siy/pyenv/lib/python3.9/site-packages/qiskit/circuit/quantumcircuit.py:1892, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order)
#    1889 # pylint: disable=cyclic-import
#    1890 from qiskit.visualization import circuit_drawer
# -> 1892 return circuit_drawer(
#    1893     self,
#    1894     scale=scale,
#    1895     filename=filename,
#    1896     style=style,
#    1897     output=output,
#    1898     interactive=interactive,
#    1899     plot_barriers=plot_barriers,
#    1900     reverse_bits=reverse_bits,
#    1901     justify=justify,
# ...

# %%
circ = transpile(circ, backend)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 circ = transpile(circ, backend)
#
# File ~/.qbraid/environments/qiskit_9y9siy/pyenv/lib/python3.9/site-packages/qiskit/compiler/transpiler.py:381, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     378     for circuit, unique_args in zip(circuits, unique_transpile_args):
#     379         transpile_config, pass_manager = _combine_args(shared_args, unique_args)
# ...

# %%
options = {"backend_name": 'ibmq_jakarta', 
           "max_execution_time":300,
           "instance":'ibm-q-startup/qbraid/reservations'}

runtime_inputs = {
    'circuits':circ, 
    'shots': 4000, 
}

job = service.run(
    program_id='circuit-runner',
    options=options,
    inputs=runtime_inputs,
)

# Job id
print(job.job_id())
# See job status
print(job.status())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 10
#       1 options = {"backend_name": 'ibmq_jakarta',
#       2            "max_execution_time":300,
#       3            "instance":'ibm-q-startup/qbraid/reservations'}
#       5 runtime_inputs = {
#       6     'circuits':circ,
#       7     'shots': 4000,
#       8 }
# ---> 10 job = service.run(
#      11     program_id='circuit-runner',
#      12     options=options,
#      13     inputs=runtime_inputs,
#      14 )
#      16 # Job id
#      17 print(job.job_id())
#
# File ~/.qbraid/environments/qiskit_9y9siy/pyenv/lib/python3.9/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:998, in QiskitRuntimeService.run(self, program_id, inputs, options, callback, result_decoder, instance, session_id, job_tags, max_execution_time, start_session)
#     995     hgp_name = hgp.name
#     997 try:
# ...
